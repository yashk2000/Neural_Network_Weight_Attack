# %% [markdown]
# # Bit Flip Attack

# %% [markdown]
# ## Download the dataset

# %%
# !wget 'https://hanlab.mit.edu/files/OnceForAll/ofa_cvpr_tutorial/imagenet_1k.zip'
# !unzip imagenet_1k.zip
# Out:
# --2021-04-18 08:11:30--  https://hanlab.mit.edu/files/OnceForAll/ofa_cvpr_tutorial/imagenet_1k.zip
# Resolving hanlab.mit.edu (hanlab.mit.edu)... 18.25.8.36
# Connecting to hanlab.mit.edu (hanlab.mit.edu)|18.25.8.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 260772586 (249M) [application/zip]
# Saving to: ‘imagenet_1k.zip’
#
# imagenet_1k.zip     100%[===================>] 248.69M  65.6MB/s    in 4.0s
#
# 2021-04-18 08:11:34 (62.4 MB/s) - ‘imagenet_1k.zip’ saved [260772586/260772586]
#
# Archive:  imagenet_1k.zip
#    creating: imagenet_1k/
#   inflating: imagenet_1k/synset_words.txt
#   inflating: imagenet_1k/labels.txt
#    creating: imagenet_1k/train/
#    creating: imagenet_1k/train/n04542943/
#   inflating: imagenet_1k/train/n04542943/ILSVRC2012_00028926.JPEG
#    creating: imagenet_1k/train/n02795169/
#   inflating: imagenet_1k/train/n02795169/ILSVRC2012_00023608.JPEG
#    creating: imagenet_1k/train/n02422699/
# ...

# %% [markdown]
# ## Check GPU

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla P4'

# %% [markdown]
# ## Clone the code from GitHub

# %%
# !git clone https://github.com/yashk2000/Neural_Network_Weight_Attack.git
# Out:
# Cloning into 'Neural_Network_Weight_Attack'...
# remote: Enumerating objects: 312, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 312 (delta 15), reused 13 (delta 6), pack-reused 278
# Receiving objects: 100% (312/312), 1.69 MiB | 11.28 MiB/s, done.
# Resolving deltas: 100% (159/159), done.

# %% [markdown]
# ### Copy the code to `/content`

# %%
# !cp -a /content/Neural_Network_Weight_Attack/. /content/

# %% [markdown]
# ## Install tensorboard

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 122kB 6.2MB/s
# ...

# %% [markdown]
# ## Execute the code

# %%
# !bash BFA_imagenet.sh
# Out:
# Current host is: 3055ab7db3fc
# save path : /content/2021-04-18/imagenet_resnet34_quan_BFA
# {'arch': 'resnet34_quan', 'attack_sample_size': 64, 'clustering': False, 'data_path': '/content/imagenet_1k', 'dataset': 'imagenet', 'decay': 0.0001, 'enable_bfa': True, 'epochs': 200, 'evaluate': False, 'fine_tune': False, 'gammas': [0.1, 0.1], 'gpu_id': 0, 'k_top': 10, 'lambda_coeff': 0.001, 'learning_rate': 0.001, 'manualSeed': 32, 'model_only': False, 'momentum': 0.9, 'n_iter': 50, 'ngpu': 1, 'optimizer': 'SGD', 'print_freq': 50, 'quan_bitwidth': None, 'random_bfa': False, 'reset_weight': True, 'resume': '', 'save_path': '/content/2021-04-18/imagenet_resnet34_quan_BFA', 'schedule': [80, 120], 'start_epoch': 0, 'test_batch_size': 256, 'use_cuda': True, 'workers': 8}
# Random Seed: 32
# python version : 3.7.10 (default, Feb 20 2021, 21:17:23)  [GCC 7.5.0]
# torch  version : 1.8.1+cu101
# cudnn  version : 7603
# ...
